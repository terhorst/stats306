# %% [markdown]
# # Read these instructions completely in order to receive full credit
#
# - Before you submit the problem set, make sure everything runs as expected. Go to the menu bar at the top of Jupyter Notebook and click `Kernel > Restart & Run All`. Your code should run from top to bottom with no errors. Failure to do this will result in loss of points.
#
# - You should not use `install.packages()` anywhere. You may assume that we have already installed all the packages needed to run your code.
#
# - Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE" and delete the `stop()` functions. The `stop()` functions produce an error and are there to remind you of cells that need an answer.
#
# - If you are working in a group, make sure you and your collaborators have been added to a group on Canvas as described at the beginning of lecture 2.
# - As a backup, *also* fill in your uniqid as well as those of your collaborators below:

# %% [markdown]
# Your uniqid: `<replace with your uniqid>`
#
# Uniqids of your collaborator(s): `<replace with their uniqids>`

# %% [markdown]
# - **Carefully proofread the PDF that you upload to Canvas. PDFs that have missing or truncated code cannot be graded and will not receive credit.**

# %% [markdown]
# ---

# %%
library(tidyverse)
library(nycflights13)
options(repr.plot.width=5, repr.plot.height=4)

# %% [markdown]
# # STATS 306
# ## Problem Set 1: Plotting and data manipulation
#
# - Each problem is worth one or two points for a total of 10.
# - For each problem, enter the R code in the cell provided marked "YOUR SOLUTION HERE".

# %% [markdown]
# ## Plots
# Enter the code neede to reproduce each of the plots below. Your plot should match the colors, axis labels & titles, plot type, orientation, and so forth. We do not care about minor visual differences in the font, plot width or height, placement of labels or annotations, etc. Using a different color scheme is fine.

# %% [markdown]
# #### Problem 1 (1 pt.)
# ![image.png](attachment:image.png)

# %%
# YOUR CODE HERE
stop()

# %% [markdown]
# ## Animals
# Problems 2-4 are based on the `animals` table, which is defined for you in the next cell.

# %%
library(MASS)
animals <- as_tibble(MASS::Animals) %>% mutate(species = rownames(MASS::Animals))

# %% [markdown]
# #### Problem 2 (1 pt.)
# ![image.png](attachment:image.png)

# %%
# YOUR CODE HERE
stop()

# %% [markdown]
# #### Problem 3 (1 pt.)
# ![image.png](attachment:image.png)

# %%
# YOUR CODE HERE
stop()

# %% [markdown]
# #### Problem 4 (1 pts.)
# The preceding plot indicates that the log of brain mass is linearly related to the log of body mass. Check this by computing the correlation of brain mass with body mass, and compare that with the correlation between the logs of those two quantities. (*Hint*: R contains a built-in function for computing the correlation of two vectors.)

# %%
# YOUR CODE HERE
stop()

# %% [markdown]
# ### Flights
# The following command shows the top five air carriers in terms of total number of departures from NYC-area airports in 2013:

# %%
flights_top5 <- count(flights, carrier) %>% top_n(5) %>% print

# %% [markdown]
# #### Problem 5 (1 pt.)
# Use `filter()` to subset the flights table down to only those top five carriers. You should end up with a table that has 248,312 rows, the first ten of which look like:
#
#     # A tibble: 248,312 x 19
#         year month   day dep_time sched_dep_time dep_delay arr_time sched_arr_time
#        <int> <int> <int>    <int>          <int>     <dbl>    <int>          <int>
#      1  2013     1     1      517            515         2      830            819
#      2  2013     1     1      533            529         4      850            830
#      3  2013     1     1      542            540         2      923            850
#      4  2013     1     1      544            545        -1     1004           1022
#      5  2013     1     1      554            600        -6      812            837
#      6  2013     1     1      554            558        -4      740            728
#      7  2013     1     1      555            600        -5      913            854
#      8  2013     1     1      557            600        -3      709            723
#      9  2013     1     1      557            600        -3      838            846
#     10  2013     1     1      558            600        -2      753            745
#     # ... with 248,302 more rows, and 11 more variables: arr_delay <dbl>,
#     #   carrier <chr>, flight <int>, tailnum <chr>, origin <chr>, dest <chr>,
#     #   air_time <dbl>, distance <dbl>, hour <dbl>, minute <dbl>, time_hour <dttm>

# %%
# YOUR CODE HERE
stop()

# %% [markdown]
# #### Problem 6 (1 pt.)
#
# Using the table you created in the previous exercise, recreate the following plot showing how many departures the top five carriers had out of each of the three NYC airports:
# ![image.png](attachment:image.png)

# %%
# YOUR CODE HERE
stop()

# %% [markdown]
# #### Problem 7 (1 pt.)
# In lecture we saw that `geom_jitter()` can be used to prevent overplotting when visualizing data that have been rounded. Another form of overplotting occurs when there are simply too many data points.
#
# The following scatter shows compares the price versus weight (measured in carats) of diamonds in the `diamonds` data set:

# %%
ggplot(diamonds) + geom_point(aes(x=carat, y=price))

# %% [markdown]
# To reduce the overplotting, we can use a heatmap to visualize the joint distribution of `carat` and `price`. Use `geom_bin2d()` or `geom_hex()` to generate such a plot:
#
# ![image.png](attachment:image.png)

# %%
# YOUR CODE HERE
stop()

# %% [markdown]
# #### Problem 8 (1 pt.)
# From the above plot, we can see that `price` and `carat` do not seem to be linearly related. However, it turns out that `log(price)` and `log(carat)` do have nearly linear relationship. Verify this by reproducing the following plot:
# ![image.png](attachment:image.png)
# (The red line indicates the regression fit.)

# %%
# YOUR CODE HERE
stop()

# %% [markdown]
# ## Challenge Problem
# Each problem set will feature one or two questions that go a bit beyond what we have covered in lab and lecture. The goal of these is for you learn how to use online resources (R's help, Google, Stack Overflow, etc.) to solve programming challenges that you have not encountered before. This is an important skill which you will use constantly as data scientists in the real world.

# %% [markdown]
# #### Problem 9 (2 pts.)
# Reproduce the following plot using the `midwest` table on socioeconomic data from midwestern towns. (See `?midwest` for column definitions.)
# ![image.png](attachment:image.png)

# %%
# YOUR CODE HERE
stop()
